# %%
! pip install pandas
# Out:
# ...
#      ---------------------------------------- 0.0/10.3 MB ? eta -:--:--
#      ---------------------------------------- 0.0/10.3 MB 1.3 MB/s eta 0:00:09
#      --------------------------------------- 0.1/10.3 MB 812.7 kB/s eta 0:00:13
#       --------------------------------------- 0.1/10.3 MB 1.1 MB/s eta 0:00:10
#       --------------------------------------- 0.2/10.3 MB 1.5 MB/s eta 0:00:07
#      - -------------------------------------- 0.3/10.3 MB 1.7 MB/s eta 0:00:07
#      - -------------------------------------- 0.4/10.3 MB 1.6 MB/s eta 0:00:07
#      -- ------------------------------------- 0.6/10.3 MB 2.2 MB/s eta 0:00:05
#      ---- ----------------------------------- 1.1/10.3 MB 3.0 MB/s eta 0:00:04
#      ----- ---------------------------------- 1.4/10.3 MB 3.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.4/10.3 MB 3.6 MB/s eta 0:00:03
#      ----- ---------------------------------- 1.5/10.3 MB 3.0 MB/s eta 0:00:03
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("people-100.csv")

# %%
df
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 0       1  88F7B33d2bcf9f5     Shelby    Terrell    Male
# 1       2  f90cD3E76f1A9b9    Phillip    Summers  Female
# 2       3  DbeAb8CcdfeFC2c   Kristine     Travis    Male
# 3       4  A31Bee3c201ef58    Yesenia   Martinez    Male
# 4       5  1bA7A3dc874da3c       Lori       Todd    Male
# ..    ...              ...        ...        ...     ...
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                   Phone Date of birth  \
# 0         elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1        bethany14@example.com       214.112.6044x4913    1910-03-24
# 2        bthompson@example.com            277.609.7938    1992-07-02
# ...

# %%
df.head()
# Out:
#    Index          User Id First Name Last Name     Sex  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male
# 3      4  A31Bee3c201ef58    Yesenia  Martinez    Male
# 4      5  1bA7A3dc874da3c       Lori      Todd    Male
#
#                         Email                   Phone Date of birth  \
# 0        elijah57@example.net  001-084-906-7849x73518    1945-10-26
# 1       bethany14@example.com       214.112.6044x4913    1910-03-24
# 2       bthompson@example.com            277.609.7938    1992-07-02
# 3   kaitlinkaiser@example.com            584.094.6111    2017-08-03
# 4  buchananmanuel@example.net       689-207-3558x7233    1938-12-01
#
#             Job Title
# 0     Games developer
# 1      Phytotherapist
# 2           Homeopath
# 3   Market researcher
# 4  Veterinary surgeon

# %%
df.head(3)
# Out:
#    Index          User Id First Name Last Name     Sex                  Email  \
# 0      1  88F7B33d2bcf9f5     Shelby   Terrell    Male   elijah57@example.net
# 1      2  f90cD3E76f1A9b9    Phillip   Summers  Female  bethany14@example.com
# 2      3  DbeAb8CcdfeFC2c   Kristine    Travis    Male  bthompson@example.com
#
#                     Phone Date of birth        Job Title
# 0  001-084-906-7849x73518    1945-10-26  Games developer
# 1       214.112.6044x4913    1910-03-24   Phytotherapist
# 2            277.609.7938    1992-07-02        Homeopath

# %%
df.tail()
# Out:
#     Index          User Id First Name  Last Name     Sex  \
# 95     96  5eFda7caAeB260E     Dennis     Barnes  Female
# 96     97  CCbFce93d3720bE      Steve  Patterson  Female
# 97     98  2fEc528aFAF0b69     Wesley       Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer   Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah    Bernard    Male
#
#                          Email                 Phone Date of birth  \
# 95         bmartin@example.org  001-095-524-2112x257    1954-07-30
# 96       latasha46@example.net      001-865-478-5157    1932-04-29
# 97        regina11@example.org    995-542-3004x76800    1994-12-28
# 98  alexiscantrell@example.org  001-273-685-6932x092    2012-04-12
# 99       pcopeland@example.org   (341)594-6554x44657    2016-11-15
#
#                 Job Title
# 95      Software engineer
# 96              Barrister
# 97         Police officer
# 98   Broadcast journalist
# 99  IT sales professional

# %%
df.tail(3)
# Out:
#     Index          User Id First Name Last Name     Sex  \
# 97     98  2fEc528aFAF0b69     Wesley      Bray    Male
# 98     99  Adc7ad9B6e4A1Fe     Summer  Oconnell  Female
# 99    100  b8D0aD3490FC7e1     Mariah   Bernard    Male
#
#                          Email                 Phone Date of birth  \
# 97        regina11@example.org    995-542-3004x76800    1994-12-28
# 98  alexiscantrell@example.org  001-273-685-6932x092    2012-04-12
# 99       pcopeland@example.org   (341)594-6554x44657    2016-11-15
#
#                 Job Title
# 97         Police officer
# 98   Broadcast journalist
# 99  IT sales professional

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
list(df.columns)
# Out:
# ['Index',
#  'User Id',
#  'First Name',
#  'Last Name',
#  'Sex',
#  'Email',
#  'Phone',
#  'Date of birth',
#  'Job Title']

# %%
df['First Name']
# Out:
# 0       Shelby
# 1      Phillip
# 2     Kristine
# 3      Yesenia
# 4         Lori
#         ...
# 95      Dennis
# 96       Steve
# 97      Wesley
# 98      Summer
# 99      Mariah
# Name: First Name, Length: 100, dtype: object

# %%
type(df['First Name'])
# Out:
# pandas.core.series.Series

# %%
df[['First Name']]
# Out:
#    First Name
# 0      Shelby
# 1     Phillip
# 2    Kristine
# 3     Yesenia
# 4        Lori
# ..        ...
# 95     Dennis
# 96      Steve
# 97     Wesley
# 98     Summer
# 99     Mariah
#
# [100 rows x 1 columns]

# %%
type(df[['First Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['Index', 'User Id', 'First Name', 'Last Name', 'Sex', 'Email', 'Phone',
#        'Date of birth', 'Job Title'],
#       dtype='object')

# %%
df[['Job Title','First Name']]
# Out:
#                 Job Title First Name
# 0         Games developer     Shelby
# 1          Phytotherapist    Phillip
# 2               Homeopath   Kristine
# 3       Market researcher    Yesenia
# 4      Veterinary surgeon       Lori
# ..                    ...        ...
# 95      Software engineer     Dennis
# 96              Barrister      Steve
# 97         Police officer     Wesley
# 98   Broadcast journalist     Summer
# 99  IT sales professional     Mariah
#
# [100 rows x 2 columns]

# %%
df.dtypes
# Out:
# Index             int64
# User Id          object
# First Name       object
# Last Name        object
# Sex              object
# Email            object
# Phone            object
# Date of birth    object
# Job Title        object
# dtype: object

# %%
df1=pd.read_excel("KDrama Series Link.xlsx")

# %%
! pip install openpyxl
# Out:
# ...
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ---- -------------------------------- 30.7/250.0 kB 640.0 kB/s eta 0:00:01
#      ------ ------------------------------ 41.0/250.0 kB 388.9 kB/s eta 0:00:01
#      ---------------- ------------------- 112.6/250.0 kB 930.9 kB/s eta 0:00:01
#      ------------------------- ---------- 174.1/250.0 kB 952.6 kB/s eta 0:00:01
#      ----------------------------------- -- 235.5/250.0 kB 1.2 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 1.0 MB/s eta 0:00:00
# ...

# %%
df1
# Out:
#                                 Name  IMDB Rating   \
# 0                                NaN           NaN
# 1   Goblin: The Lonely and Great God           8.6
# 2                                NaN           NaN
# 3                           My Name            7.8
# 4                                NaN           NaN
# 5                           Vincenco           8.4
# 6                                NaN           NaN
# 7                        True Beauty           8.0
# 8                                NaN           NaN
# 9                       Little Woman           8.0
# 10                               NaN           NaN
# 11                               NaN           NaN
# 12                The Great Show S01           7.2
# 13                               NaN           NaN
# 14                      Youth of May           8.4
# 15                               NaN           NaN
# 16                       Melancholia           7.3
# ...

# %%
type(df1)
# Out:
# pandas.core.frame.DataFrame

# %%
df1.dtypes
# Out:
# Name               object
# IMDB Rating       float64
# Link to Watch      object
# No of Episodes     object
# dtype: object

# %%
df1.columns
# Out:
# Index(['Name', 'IMDB Rating ', 'Link to Watch ', 'No of Episodes'], dtype='object')

# %%
df1[['Name','No of Episodes']]
# Out:
#                                 Name No of Episodes
# 0                                NaN            NaN
# 1   Goblin: The Lonely and Great God        1 to 16
# 2                                NaN            NaN
# 3                           My Name          1 to 8
# 4                                NaN            NaN
# 5                           Vincenco        1 to 15
# 6                                NaN            NaN
# 7                        True Beauty        1 to 16
# 8                                NaN            NaN
# 9                       Little Woman      1 to 12
# 10                               NaN            NaN
# 11                               NaN            NaN
# 12                The Great Show S01        1 to 16
# 13                               NaN            NaN
# 14                      Youth of May        1 to 12
# 15                               NaN            NaN
# 16                       Melancholia        1 to 16
# ...

# %%
df2=pd.read_csv('https://media.githubusercontent.com/media/datablist/sample-csv-files/main/files/organizations/organizations-100.csv')

# %%
df2
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
df2.columns
# Out:
# Index(['Index', 'Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
df2[['Organization Id','Industry']]
# Out:
#     Organization Id                     Industry
# 0   FAB0d41d5b5d22c                     Plastics
# 1   6A7EdDEA9FaDC52  Glass / Ceramics / Concrete
# 2   0bFED1ADAE4bcC1                Public Safety
# 3   2bFC1Be8a4ce42f                   Automotive
# 4   9eE8A6a4Eb96C24               Transportation
# ..              ...                          ...
# 95  0a0bfFbBbB8eC7c                  Photography
# 96  BA6Cd9Dae2Efd62            Consumer Services
# 97  E7df80C60Abd7f9              Broadcast Media
# 98  AFc285dbE2fEd24         Education Management
# 99  e9eB5A60Cef8354           Financial Services
#
# [100 rows x 2 columns]

# %%
type(df2[['Organization Id','Industry']])
# Out:
# pandas.core.frame.DataFrame

# %%
df2.tail(3)
# Out:
#     Index  Organization Id               Name                  Website  \
# 97     98  E7df80C60Abd7f9  Clements-Espinoza  http://www.flowers.net/
# 98     99  AFc285dbE2fEd24         Mendez Inc   https://www.burke.net/
# 99    100  e9eB5A60Cef8354     Watkins-Kaiser  http://www.herring.com/
#
#                         Country                      Description  Founded  \
# 97  Falkland Islands (Malvinas)          Progressive modular hub     1991
# 98              Kyrgyz Republic  User-friendly exuding migration     1993
# 99                         Togo    Synergistic background access     2009
#
#                 Industry  Number of employees
# 97       Broadcast Media                  236
# 98  Education Management                  339
# 99    Financial Services                 2785

# %%
import lxml
import pandas as pd
df3=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2022_totals.html')

# %%
type(df3)
# Out:
# list

# %%
len(df3)
# Out:
# 1

# %%
df3=df3[0]

# %%
df3
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  1725  265   603  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  1999  210   384  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  1825  406   729  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0   360   53   132  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252   458  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
# 838  602         Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
# 839  603     Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
# 840  604        Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
# 841  605        Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
# ...

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3.head()
# Out:
#   Rk             Player Pos Age   Tm   G  GS    MP   FG  FGA  ...   FT%  ORB  \
# 0  1   Precious Achiuwa   C  22  TOR  73  28  1725  265  603  ...  .595  146
# 1  2       Steven Adams   C  28  MEM  76  75  1999  210  384  ...  .543  349
# 2  3        Bam Adebayo   C  24  MIA  56  56  1825  406  729  ...  .753  137
# 3  4       Santi Aldama  PF  21  MEM  32   0   360   53  132  ...  .625   33
# 4  5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252  458  ...  .873   73
#
#    DRB  TRB  AST STL BLK  TOV   PF   PTS
# 0  327  473   82  37  41   84  151   664
# 1  411  760  256  65  60  115  153   528
# 2  427  564  190  80  44  148  171  1068
# 3   54   87   21   6  10   16   36   132
# 4  185  258   42  14  47   44   78   607
#
# [5 rows x 30 columns]

# %%
df3.tail()
# Out:
#       Rk          Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 837  601  Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
# 838  602      Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
# 839  603  Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
# 840  604     Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
# 841  605     Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
#      ORB  DRB  TRB  AST STL BLK  TOV   PF   PTS
# 837   40   75  115   45  31  11   22   43   164
# 838   50  234  284  737  72   7  303  128  2155
# 839   85  209  294   49  17  20   41   84   299
# 840   50   75  125   22   8   6   19   56   140
# 841  217  427  644  120  36  77  114  203   785
#
# [5 rows x 30 columns]

# %%
df3.columns
# Out:
# Index(['Rk', 'Player', 'Pos', 'Age', 'Tm', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%',
#        '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%',
#        'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS'],
#       dtype='object')

# %%
df3[['Rk','Player','Age']]
# Out:
#       Rk             Player Age
# 0      1   Precious Achiuwa  22
# 1      2       Steven Adams  28
# 2      3        Bam Adebayo  24
# 3      4       Santi Aldama  21
# 4      5  LaMarcus Aldridge  36
# ..   ...                ...  ..
# 837  601     Thaddeus Young  33
# 838  602         Trae Young  23
# 839  603     Omer Yurtseven  23
# 840  604        Cody Zeller  29
# 841  605        Ivica Zubac  24
#
# [842 rows x 3 columns]

# %%
df3.to_csv('players_data.csv',index=False)

# %%
# Out:
#       Rk             Player Pos Age   Tm   G  GS    MP   FG   FGA  ...   FT%  \
# 0      1   Precious Achiuwa   C  22  TOR  73  28  1725  265   603  ...  .595
# 1      2       Steven Adams   C  28  MEM  76  75  1999  210   384  ...  .543
# 2      3        Bam Adebayo   C  24  MIA  56  56  1825  406   729  ...  .753
# 3      4       Santi Aldama  PF  21  MEM  32   0   360   53   132  ...  .625
# 4      5  LaMarcus Aldridge   C  36  BRK  47  12  1050  252   458  ...  .873
# ..   ...                ...  ..  ..  ...  ..  ..   ...  ...   ...  ...   ...
# 837  601     Thaddeus Young  PF  33  TOR  26   0   475   67   144  ...  .481
# 838  602         Trae Young  PG  23  ATL  76  76  2652  711  1544  ...  .904
# 839  603     Omer Yurtseven   C  23  MIA  56  12   706  130   247  ...  .623
# 840  604        Cody Zeller   C  29  POR  27   0   355   51    90  ...  .776
# 841  605        Ivica Zubac   C  24  LAC  76  76  1852  310   495  ...  .727
#
# ...
