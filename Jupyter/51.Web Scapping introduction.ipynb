# %%
import requests
from bs4 import BeautifulSoup as bs
from urllib.request import urlopen as uRequest
import logging

# %%
flipkart_url="https://www.flipkart.com/search?q=" +"iphone14pro"

# %%
flipkart_url
# Out:
# 'https://www.flipkart.com/search?q=iphone14pro'

# %%
urlclient=uRequest(flipkart_url)

# %%
flipkart_page=urlclient.read()

# %%
flipkart_html=bs(flipkart_page,'html.parser')

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
"https://www.flipkart.com/search?q=iphone%2014%20pro%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"
# Out:
# 'https://www.flipkart.com/search?q=iphone%2014%20pro%20&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off'

# %%
flipkart_html
# Out:
# <!DOCTYPE html>
# ...

# %%
bigbox=flipkart_html.findAll("div",{"class":"_1AtVbE col-12-12"})

# %%
len(bigbox)
# Out:
# 29

# %%
del bigbox[0:3]

# %%
product_link="https://flipkart.com" + bigbox[3].div.div.div.a['href']

# %%
product_link
# Out:
# 'https://flipkart.com/apple-iphone-14-pro-gold-128-gb/p/itme5895e593585d?pid=MOBGHWFHXPC3NFFY&lid=LSTMOBGHWFHXPC3NFFYGGZRVC&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_5&otracker=search&fm=organic&iid=41762842-e30b-4711-96e0-47ebcd0908c4.MOBGHWFHXPC3NFFY.SEARCH&ppt=None&ppn=None&ssid=yzp6c7qfb40000001680323494169&qH=1b57eea67220f216'

# %%
product_req=requests.get(product_link)

# %%
produt_html=bs(product_req.text,'html.parser')

# %%
comments_box=produt_html.find_all('div',{"class":"_16PBlm"})

# %%
len(comments_box)
# Out:
# 11

# %%
comments_box
# Out:
# [<div class="_16PBlm"><div class="col"><div class="col _2wzgFH"><div class="row"><div class="_3LWZlK _1BLPMq">5<img class="_1wB99o" src="..."/></div><p class="_2-N8zT">Excellent</p></div><div class="row"><div class="t-ZTKy"><div><div class="">Upgraded from XR to 14 pro, amazing phone with advanced features limited to just pro models, stock availability is too low. Got mine by luck!<br/>If youre upgrading from iPhone 11 /11 pro  and below you'll love the update</div><span class="_1H-bmy"><span>READ MORE</span></span></div></div></div><div class="_2nMSwX _3oLIki"><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_3faf39e6265c4a35821ee0e2b89484a5.jpg?q=90), url(data:image/svg+xml;base64,...);width:62px;height:62px"></div><div class="_21YjFX _2A07HP" style="background-image:url(https://rukminim1.flixcart.com/blobio/124/124/imr/blobio-imr_44a6dd0890a247299a5d0962004af6f4.jpg?q=90), url(data:image/svg+xml;base64,...);width:
# ...

# %%
comments_box[0].div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text
# Out:
# 'Debasish Rout'

# %%
for i in comments_box:
    print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
# Out:
# Debasish Rout
# Neelendra  Singh
# Sarvesh Saxena
# Gautam Aggarwal
# Vaibhav Agrawal
# Subham Roy
# Salman khan
# Flipkart Customer
# Ashutosh Gupta
# Pratik Raj
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[75], line 2
#       1 for i in comments_box:
# ----> 2     print(i.div.div.find_all('p',{"class":"_2sc7ZR _2V5EHH"})[0].text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
for i in comments_box:
    print(i.div.div.p.text)
# Out:
# Excellent
# Just wow!
# Wonderful
# Brilliant
# Highly recommended
# Must buy!
# Brilliant
# Worth every penny
# Great product
# Best in the market!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 2
#       1 for i in comments_box:
# ----> 2     print(i.div.div.p.text)
#
# AttributeError: 'NoneType' object has no attribute 'div'

# %%
comments_box[0].div.div.find_all('div',{"class":''})[0].div.text
# Out:
# "Upgraded from XR to 14 pro, amazing phone with advanced features limited to just pro models, stock availability is too low. Got mine by luck!If youre upgrading from iPhone 11 /11 pro  and below you'll love the update"

# %%
for i in comments_box:
    print(i.div.div.find_all('div',{"class":''})[0].div.text)
# Out:
# Upgraded from XR to 14 pro, amazing phone with advanced features limited to just pro models, stock availability is too low. Got mine by luck!If youre upgrading from iPhone 11 /11 pro  and below you'll love the update
# Worth the Money✨Brilliant life batteryThe wallpaper and customisation updates are awesomeThe camera clicks a very clear picEkart made a super fast delivery👍Thanks Ekart!
# Upgraded from iPhone 11 pro to iPhone 14 pro, awesome phone camera, Display quality good very fast delivery.⭐️⭐️⭐️⭐️⭐️
# Fantastic product even though it's just an iterative upgrade to iphone 13 pro. The deep purple looks purple when the light hits the phone a certain way and it's beautiful. Dynamic island is very practical and useful. Hopefully it will get better when 3rd party developers start making use of it.Flipkart's delivery was quick and hassle free. The order was delivered on the launch date and was packed well.
# ...

# %%
for i in bigbox:
    print ("htttps://flipkart.com" +i.div.div.div.a['href'])
# Out:
# htttps://flipkart.com/apple-iphone-14-pro-deep-purple-256-gb/p/itmfbeb0684432d7?pid=MOBGHWFHR4ZYUPH5&lid=LSTMOBGHWFHR4ZYUPH5XVPV0K&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_2&otracker=search&fm=organic&iid=59b3ea1e-7a53-4c62-ae71-890ea46cc95c.MOBGHWFHR4ZYUPH5.SEARCH&ppt=None&ppn=None&ssid=h0btlltm6o0000001680323295998&qH=1b57eea67220f216
# htttps://flipkart.com/apple-iphone-14-pro-silver-128-gb/p/itm6933eb5fb30fb?pid=MOBGHWFHGQGUHWRK&lid=LSTMOBGHWFHGQGUHWRKM5ZB1P&marketplace=FLIPKART&q=iphone14pro&store=tyy%2F4io&srno=s_1_3&otracker=search&fm=organic&iid=59b3ea1e-7a53-4c62-ae71-890ea46cc95c.MOBGHWFHGQGUHWRK.SEARCH&ppt=None&ppn=None&ssid=h0btlltm6o0000001680323295998&qH=1b57eea67220f216
# ...
