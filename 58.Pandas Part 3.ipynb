# %%
import pandas as pd

# %%
df= pd.read_csv("https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv")

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
s=df['Name']

# %%
len(s)
# Out:
# 891

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
s=df['Name'][0:10]

# %%
s
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %%
len(s)
# Out:
# 10

# %%
l=[ 'a','b','c','d','e','f','g','h','i','j']

# %%
s1=pd.Series(list(s),index=l)

# %%
s1
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s1[0]
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s1['a']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
s2=s1.append(s)
# Out:
# C:\Users\RomulusDome\AppData\Local\Temp\ipykernel_12340\3117856201.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2=s1.append(s)

# %%
s2=s1.append(s)
# Out:
# C:\Users\RomulusDome\AppData\Local\Temp\ipykernel_12340\2552242485.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s2=s1.append(s)

# %%
s2
# Out:
# a                              Braund, Mr. Owen Harris
# b    Cumings, Mrs. John Bradley (Florence Briggs Th...
# c                               Heikkinen, Miss. Laina
# d         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# e                             Allen, Mr. William Henry
# f                                     Moran, Mr. James
# g                              McCarthy, Mr. Timothy J
# h                       Palsson, Master. Gosta Leonard
# i    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# j                  Nasser, Mrs. Nicholas (Adele Achem)
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# dtype: object

# %%
s2[4]
# Out:
# 'Allen, Mr. William Henry'

# %%
s4 = pd.Series([3,4,6,7,8],index=[2,3,5,6,1])

# %%
s4
# Out:
# 2    3
# 3    4
# 5    6
# 6    7
# 1    8
# dtype: int64

# %%
s5= pd.Series([3,44,55,66,77],index=[9,4,5,6,7])

# %%
s6=s4.append(s5)
# Out:
# C:\Users\RomulusDome\AppData\Local\Temp\ipykernel_12340\884104408.py:1: FutureWarning: The series.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   s6=s4.append(s5)

# %%
s6
# Out:
# 2     3
# 3     4
# 5     6
# 6     7
# 1     8
# 9     3
# 4    44
# 5    55
# 6    66
# 7    77
# dtype: int64

# %%
s6[6]
# Out:
# 6     7
# 6    66
# dtype: int64

# %%
s6[0:9]
# Out:
# 2     3
# 3     4
# 5     6
# 6     7
# 1     8
# 9     3
# 4    44
# 5    55
# 6    66
# dtype: int64

# %%
s4*s5
# Out:
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
# 5    330.0
# 6    462.0
# 7      NaN
# 9      NaN
# dtype: float64

# %%
import requests
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 import requests
#
# ModuleNotFoundError: No module named 'requests'

# %%
! pip install requests
# Out:
# Collecting requests
#   Using cached requests-2.28.2-py3-none-any.whl (62 kB)
# Collecting charset-normalizer<4,>=2
#   Downloading charset_normalizer-3.1.0-cp311-cp311-win_amd64.whl (96 kB)
#      ---------------------------------------- 0.0/96.7 kB ? eta -:--:--
#      ------------ --------------------------- 30.7/96.7 kB ? eta -:--:--
#      ------------ --------------------------- 30.7/96.7 kB ? eta -:--:--
#      ------------------------------------ - 92.2/96.7 kB 751.6 kB/s eta 0:00:01
#      -------------------------------------- 96.7/96.7 kB 691.6 kB/s eta 0:00:00
# Requirement already satisfied: idna<4,>=2.5 in c:\users\romulusdome\appdata\local\packages\pythonsoftwarefoundation.python.3.11_qbz5n2kfra8p0\localcache\local-packages\python311\site-packages (from requests) (3.4)
# Collecting urllib3<1.27,>=1.21.1
#   Downloading urllib3-1.26.15-py2.py3-none-any.whl (140 kB)
#      ---------------------------------------- 0.0/140.9 kB ? eta -:--:--
#      ------------------------------ ------- 112.6/140.9 kB 2.2 MB/s eta 0:00:01
#      ----------------------------------- -- 133.1/140.9 kB 1.6 MB/s eta 0:00:01
#      -------------------------------------- 140.9/140.9 kB 1.4 MB/s eta 0:00:00
# Collecting certifi>=2017.4.17
#   Downloading certifi-2022.12.7-py3-none-any.whl (155 kB)
#      ---------------------------------------- 0.0/155.3 kB ? eta -:--:--
#      --------------------------- ---------- 112.6/155.3 kB 6.4 MB/s eta 0:00:01
#      -------------------------------------- 155.3/155.3 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: urllib3, charset-normalizer, certifi, requests
# Successfully installed certifi-2022.12.7 charset-normalizer-3.1.0 requests-2.28.2 urllib3-1.26.15

# %%
import requests

# %%
url = "https://api.github.com/repos/pandas-dev/pandas/issues"

# %%
resp =requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
data =resp.json()

# %%
data
# Out:
# [{'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52098',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52098/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52098/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52098/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52098',
#   'id': 1633085792,
#   'node_id': 'I_kwDOAA0YD85hVulg',
#   'number': 52098,
#   'title': 'BUG: `bar_label()` on Series bar plot (`.plot()`) displays values off by 1',
#   'user': {'login': 'kakumarabhishek',
#    'id': 7644965,
#    'node_id': 'MDQ6VXNlcjc2NDQ5NjU=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7644965?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kakumarabhishek',
#    'html_url': 'https://github.com/kakumarabhishek',
#    'followers_url': 'https://api.github.com/users/kakumarabhishek/followers',
#    'following_url': 'https://api.github.com/users/kakumarabhishek/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kakumarabhishek/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kakumarabhishek/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kakumarabhishek/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kakumarabhishek/orgs',
#    'repos_url': 'https://api.github.com/users/kakumarabhishek/repos',
#    'events_url': 'https://api.github.com/users/kakumarabhishek/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kakumarabhishek/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-03-21T01:11:43Z',
#   'updated_at': '2023-03-21T01:11:43Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport numpy as np\r\n\r\ndata = np.array([10000, 1000, 100, 10, 5, 1])\r\n \r\nser = pd.Series(data, index=[1, 2, 3, 4, 5, 6])\r\n\r\nprint(ser)\r\n\r\nax = ser.sort_index().plot(log=True, kind="bar")\r\n\r\nfor container in ax.containers:\r\n    ax.bar_label(container)\n```\n\n\n### Issue Description\n\nI am trying to plot a bar chart from a Pandas series using the inbuilt `.plot()` attribute, and the values in the bar chart are 1 more than the values in the series.\r\n\r\nFor the code snippet above, here is the output and the generated plot:\r\n\r\n```\r\n1    10000\r\n2     1000\r\n3      100\r\n4       10\r\n5        5\r\n6        1\r\ndtype: int64\r\n```\r\n\r\n[![enter image description here][1]][1]\r\n\r\nAs you can see, the value annotations in the bar chart are off by 1.\r\n\r\n[1]: https://i.stack.imgur.com/q2Et8.png\n\n### Expected Behavior\n\nSetting the scale of the y-axis to logarithmic using matplotlib seems to resolve the issue.\r\n\r\n```\r\nimport pandas as pd\r\nimport numpy as np\r\nimport matplotlib.pyplot as plt\r\n\r\ndata = np.array([10000, 1000, 100, 10, 5, 1])\r\n \r\nser = pd.Series(data, index=[1, 2, 3, 4, 5, 6])\r\n\r\nprint(ser)\r\n\r\nax = ser.sort_index().plot(kind="bar")\r\n\r\nfor container in ax.containers:\r\n    ax.bar_label(container)\r\n\r\nplt.yscale("log")\r\n```\r\n\r\n[![enter image description here][1]][1]\r\n\r\n[1]: https://i.stack.imgur.com/f2HMd.png\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.9.16.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.147+\r\nVersion          : #1 SMP Sat Dec 10 16:00:40 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.22.4\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 63.4.3\r\npip              : 22.0.4\r\nCython           : 0.29.33\r\npytest           : 3.6.4\r\nhypothesis       : None\r\nsphinx           : 3.5.4\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.2\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : 2.9.5\r\njinja2           : 3.1.2\r\nIPython          : 7.9.0\r\npandas_datareader: 0.10.0\r\nbs4              : 4.11.2\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : 2023.3.0\r\ngcsfs            : None\r\nmatplotlib       : 3.7.1\r\nnumba            : 0.56.4\r\nnumexpr          : 2.8.4\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : 0.17.9\r\npyarrow          : 9.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : 1.10.1\r\nsnappy           : None\r\nsqlalchemy       : 1.4.46\r\ntables           : 3.7.0\r\ntabulate         : 0.8.10\r\nxarray           : 2022.12.0\r\nxlrd             : 2.0.1\r\nxlwt             : 1.3.0\r\nzstandard        : None\r\ntzdata           : 2022.7\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52098/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52098/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52097',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52097/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52097/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52097/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52097',
#   'id': 1633053430,
#   'node_id': 'PR_kwDOAA0YD85MgCwQ',
#   'number': 52097,
#   'title': 'DOC: improve (dark) theme getting started tutorials',
#   'user': {'login': 'stijnvanhoey',
#    'id': 754862,
#    'node_id': 'MDQ6VXNlcjc1NDg2Mg==',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/754862?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/stijnvanhoey',
#    'html_url': 'https://github.com/stijnvanhoey',
#    'followers_url': 'https://api.github.com/users/stijnvanhoey/followers',
#    'following_url': 'https://api.github.com/users/stijnvanhoey/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/stijnvanhoey/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/stijnvanhoey/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/stijnvanhoey/subscriptions',
#    'organizations_url': 'https://api.github.com/users/stijnvanhoey/orgs',
#    'repos_url': 'https://api.github.com/users/stijnvanhoey/repos',
#    'events_url': 'https://api.github.com/users/stijnvanhoey/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/stijnvanhoey/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-03-21T00:21:48Z',
#   'updated_at': '2023-03-21T08:59:26Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52097',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52097',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52097.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52097.patch',
#    'merged_at': None},
#   'body': '- [x] closes #51860 \r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nThis PR updates thes CSS relevant for the getting started section  of the documentation to make sure the available css-variables of the pydata-sphinx-theme are used instead of custom css-colors. As such, the pages will also work in dark-mode (as colors are adjusted based on the used variable names).\r\n\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52097/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52097/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52096',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52096/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52096/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52096/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52096',
#   'id': 1632954655,
#   'node_id': 'PR_kwDOAA0YD85MftWx',
#   'number': 52096,
#   'title': 'ENH: support na_action in SparseArray.map ',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-03-20T22:22:25Z',
#   'updated_at': '2023-03-21T07:23:18Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52096',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52096',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52096.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52096.patch',
#    'merged_at': None},
#   'body': '- [x] closes #52095\r\n- [x] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [x] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [x] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [x] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nFollowup to #51809.',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52096/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52096/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52095',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52095/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52095/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52095/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52095',
#   'id': 1632933850,
#   'node_id': 'I_kwDOAA0YD85hVJfa',
#   'number': 52095,
#   'title': 'BUG: SparseArray.map allows the fill value to be included in the sparse values',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-03-20T22:04:51Z',
#   'updated_at': '2023-03-20T22:04:51Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n>>> import pandas as pd\r\n>>> sp = pd.arrays.SparseArray([1, np.nan])\r\n>>> mapped = sp.map(lambda x: np.nan)\r\n>>> pd.isna(mapped.fill_value)\r\nTrue\r\n>>> pd.isna(mapped.sp_values)[0]\r\nTrue\n```\n\n\n### Issue Description\n\nThe current implementation of `SparseArray.map` allows the fill value to be included in the sparse values, causing potential problems.\r\n\r\n\n\n### Expected Behavior\n\n`SparseArray.map` It should raise or recalculate the sparse array.\n\n### Installed Versions\n\n<details>\r\n\r\nReplace this line with the output of pd.show_versions()\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52095/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52095/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52094',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52094/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52094/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52094/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52094',
#   'id': 1632918311,
#   'node_id': 'I_kwDOAA0YD85hVFsn',
#   'number': 52094,
#   'title': "BUG: inconsistent returned types for `pd.to_datetime(..., errors='coerce')`",
#   'user': {'login': 'pdemarti',
#    'id': 3476312,
#    'node_id': 'MDQ6VXNlcjM0NzYzMTI=',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3476312?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/pdemarti',
#    'html_url': 'https://github.com/pdemarti',
#    'followers_url': 'https://api.github.com/users/pdemarti/followers',
#    'following_url': 'https://api.github.com/users/pdemarti/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/pdemarti/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/pdemarti/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/pdemarti/subscriptions',
#    'organizations_url': 'https://api.github.com/users/pdemarti/orgs',
#    'repos_url': 'https://api.github.com/users/pdemarti/repos',
#    'events_url': 'https://api.github.com/users/pdemarti/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/pdemarti/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 211840,
#     'node_id': 'MDU6TGFiZWwyMTE4NDA=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Timeseries',
#     'name': 'Timeseries',
#     'color': 'AFEEEE',
#     'default': False,
#     'description': None}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-03-20T21:52:22Z',
#   'updated_at': '2023-03-20T22:19:08Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\n\r\n>>> pd.__version__\r\n\'1.5.3\'\r\n\r\ns = [\'2023-01-02\', \'Mon Mar 20 11:00:00 UTC 2023\', \'\', \'NaN\', \'foo\', float(\'NaN\')]\r\n\r\n>>> pd.to_datetime(s, errors=\'coerce\')\r\nIndex([2023-01-02 00:00:00, 2023-03-20 11:00:00+00:00, \'NaT\', \'NaT\', NaT, nan], dtype=\'object\')\r\n\r\n>>> [type(x) for x in pd.to_datetime(s, errors=\'coerce\')]\r\n[datetime.datetime,\r\n datetime.datetime,\r\n str,\r\n str,\r\n pandas._libs.tslibs.nattype.NaTType,\r\n float]\n```\n\n\n### Issue Description\n\nAccording to the docs, `errors=\'coerce\'` should convert entries to either a proper `datetime`, or `NaT`. Instead, we get a mix of:\r\n* `datetime`,\r\n* `float(\'NaN\')`,\r\n* `pandas._libs.tslibs.nattype.NaTType`,\r\n* `\'NaT\'` as string.\r\n\r\nThis makes it very difficult to have some consistent handling of the errors.\r\n\r\nFor example, instead of:\r\n\r\n```python\r\ns = pd.Series(...)\r\nres = pd.to_datetime(s, errors=\'coerce\')\r\ns.loc[res.isna()]\r\n```\r\n\r\nto inspect the problematic input, we have to handle string `\'NaT\'` as well as `.isna()`. The `float` `NaN` is also unexpected in that context.\n\n### Expected Behavior\n\nThe result should only contain `NaT` (as type `pandas._libs.tslibs.nattype.NaTType`) for entries where entries that failed to convert. All others should be valid `datetime` values. There should be no string `\'NaN\'` nor float `nan` in the results.\r\n\r\nA simple `.isna()` should indicate all the entries that were not successfully parsed and converted.\n\n### Installed Versions\n\n<details>\r\n\r\n```none\r\n/mnt/miniconda3/envs/test/lib/python3.10/site-packages/_distutils_hack/__init__.py:33: UserWarning: Setuptools is replacing distutils.\r\n  warnings.warn("Setuptools is replacing distutils.")\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.10.9.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 4.14.281-212.502.amzn2.x86_64\r\nVersion          : #1 SMP Thu May 26 09:52:17 UTC 2022\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.23.5\r\npytz             : 2022.7\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.6.3\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : 7.1.2\r\nhypothesis       : 6.29.3\r\nsphinx           : 5.0.2\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : 2.9.3\r\njinja2           : 3.1.2\r\nIPython          : 8.10.0\r\npandas_datareader: 0.10.0\r\nbs4              : 4.11.1\r\nbottleneck       : 1.3.5\r\nbrotli           : \r\nfastparquet      : None\r\nfsspec           : 2022.11.0\r\ngcsfs            : None\r\nmatplotlib       : 3.6.2\r\nnumba            : 0.56.4\r\nnumexpr          : 2.8.4\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npandas_gbq       : None\r\npyarrow          : 8.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : 2022.11.0\r\nscipy            : 1.10.0\r\nsnappy           : None\r\nsqlalchemy       : 1.4.39\r\ntables           : 3.7.0\r\ntabulate         : None\r\nxarray           : 2022.11.0\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard    ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52094/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52094/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52093',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52093/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52093/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52093/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52093',
#   'id': 1632814814,
#   'node_id': 'I_kwDOAA0YD85hUsbe',
#   'number': 52093,
#   'title': 'BUG: AttributeError raised with pd.concat between a None and Timestamp',
#   'user': {'login': 'christensendaniel',
#    'id': 61754368,
#    'node_id': 'MDQ6VXNlcjYxNzU0MzY4',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61754368?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/christensendaniel',
#    'html_url': 'https://github.com/christensendaniel',
#    'followers_url': 'https://api.github.com/users/christensendaniel/followers',
#    'following_url': 'https://api.github.com/users/christensendaniel/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/christensendaniel/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/christensendaniel/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/christensendaniel/subscriptions',
#    'organizations_url': 'https://api.github.com/users/christensendaniel/orgs',
#    'repos_url': 'https://api.github.com/users/christensendaniel/repos',
#    'events_url': 'https://api.github.com/users/christensendaniel/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/christensendaniel/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 0,
#   'created_at': '2023-03-20T20:31:01Z',
#   'updated_at': '2023-03-20T20:31:01Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\ndata = [{\'A\':None}]\r\ndf = pd.DataFrame(data)\r\ndata_2 = [{\'A\': pd.to_datetime("1990-12-20 00:00:00+00:00")}]\r\ndf_2 = pd.DataFrame(data_2)\r\npd.concat([df, df_2])\n```\n\n\n### Issue Description\n\nWhen running `pd.concat` between two DataFrame: one with `None` as an object, and a second, with a timezone-enabled `pandas._libs.tslibs.timestamps.Timestamp` an `AttributeError` is raised.\r\n\r\n```\r\nAttributeError: \'NoneType\' object has no attribute \'value\'\r\n```\n\n### Expected Behavior\n\nI expect this to return the same response when a non-timezone-enabled `pandas._libs.tslibs.timestamps.Timestamp`, which is the `None` changes to a `pd.NaT`\n\n### Installed Versions\n\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : c2a7f1ae753737e589617ebaaff673070036d653\r\npython           : 3.11.2.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.10.102.1-microsoft-standard-WSL2\r\nVersion          : #1 SMP Wed Mar 2 00:30:59 UTC 2022\r\nmachine          : x86_64\r\nprocessor        :\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : C.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 2.0.0rc1\r\nnumpy            : 1.24.2\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.5.1\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : None\r\nqtpy             : None\r\npyqt5            : None',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52093/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52093/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52092',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52092/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52092/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52092/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52092',
#   'id': 1632766788,
#   'node_id': 'PR_kwDOAA0YD85MfEt0',
#   'number': 52092,
#   'title': 'DOC: Remove old SparseDataFrame/SparseSeries references',
#   'user': {'login': 'topper-123',
#    'id': 26364415,
#    'node_id': 'MDQ6VXNlcjI2MzY0NDE1',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/26364415?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/topper-123',
#    'html_url': 'https://github.com/topper-123',
#    'followers_url': 'https://api.github.com/users/topper-123/followers',
#    'following_url': 'https://api.github.com/users/topper-123/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/topper-123/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/topper-123/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/topper-123/subscriptions',
#    'organizations_url': 'https://api.github.com/users/topper-123/orgs',
#    'repos_url': 'https://api.github.com/users/topper-123/repos',
#    'events_url': 'https://api.github.com/users/topper-123/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/topper-123/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 134699,
#     'node_id': 'MDU6TGFiZWwxMzQ2OTk=',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Docs',
#     'name': 'Docs',
#     'color': '3465A4',
#     'default': False,
#     'description': None},
#    {'id': 49182326,
#     'node_id': 'MDU6TGFiZWw0OTE4MjMyNg==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Sparse',
#     'name': 'Sparse',
#     'color': '009800',
#     'default': False,
#     'description': 'Sparse Data Type'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/103',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/103/labels',
#    'id': 9068593,
#    'node_id': 'MI_kwDOAA0YD84AimAx',
#    'number': 103,
#    'title': '2.1',
#    'description': '',
#    'creator': {'login': 'phofl',
#     'id': 61934744,
#     'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/phofl',
#     'html_url': 'https://github.com/phofl',
#     'followers_url': 'https://api.github.com/users/phofl/followers',
#     'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#     'organizations_url': 'https://api.github.com/users/phofl/orgs',
#     'repos_url': 'https://api.github.com/users/phofl/repos',
#     'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/phofl/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 9,
#    'closed_issues': 180,
#    'state': 'open',
#    'created_at': '2023-02-20T21:04:36Z',
#    'updated_at': '2023-03-20T22:27:19Z',
#    'due_on': '2023-08-20T07:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-03-20T19:55:54Z',
#   'updated_at': '2023-03-21T06:11:32Z',
#   'closed_at': None,
#   'author_association': 'CONTRIBUTOR',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52092',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52092',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52092.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52092.patch',
#    'merged_at': None},
#   'body': "`SparseDataFrame`/`SparseSeries` were removed in v1.0, so it's time to remove the migration docs.",
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52092/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52092/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52091',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52091/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52091/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52091/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52091',
#   'id': 1632637435,
#   'node_id': 'I_kwDOAA0YD85hUBH7',
#   'number': 52091,
#   'title': 'BUG or as expected/designed?: Generating timestamps and calculation?',
#   'user': {'login': 'kaibir',
#    'id': 69897337,
#    'node_id': 'MDQ6VXNlcjY5ODk3MzM3',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69897337?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/kaibir',
#    'html_url': 'https://github.com/kaibir',
#    'followers_url': 'https://api.github.com/users/kaibir/followers',
#    'following_url': 'https://api.github.com/users/kaibir/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/kaibir/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/kaibir/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/kaibir/subscriptions',
#    'organizations_url': 'https://api.github.com/users/kaibir/orgs',
#    'repos_url': 'https://api.github.com/users/kaibir/repos',
#    'events_url': 'https://api.github.com/users/kaibir/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/kaibir/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 3713792788,
#     'node_id': 'LA_kwDOAA0YD87dW_sU',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Non-Nano',
#     'name': 'Non-Nano',
#     'color': '006b75',
#     'default': False,
#     'description': 'datetime64/timedelta64 with non-nanosecond resolution'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 1,
#   'created_at': '2023-03-20T18:15:54Z',
#   'updated_at': '2023-03-20T18:22:46Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\nimport pandas as pd\r\nimport pytest\r\n\r\nt=pd.Timestamp("010120")\r\nprint(t.unit)\r\nprint(t.min, type(t.min))\r\nprint(t.max, type(t.max))\r\n\r\nt2=pd.Timestamp(2020,1,1)\r\nprint(t2.unit)\r\nprint(t2.min, type(t2.min))\r\nprint(t2.max, type(t2.max))\r\n\r\n\r\nwith pytest.raises(ValueError):\r\n    pd.Timestamp(10000,1,1)\n```\n\n\n### Issue Description\n\nWhile preparing our code for Pandas 2, we noticed the following:\r\n\r\n**1. Different ways of Timestamp creation ends up in a different timestamp unit**\r\n\r\n`pd.Timestamp("010120")` -> Timestamp(\'2020-01-01 00:00:00\') with `unit = \'s\'`\r\n`pd.Timestamp(2020, 1, 1)` -> Timestamp(\'2020-01-01 00:00:00\') with `unit = \'us\'\r\n\r\nMoreover I could create Timestamps, which I cannot reproduce with using `pd.Timestamp`.\r\n\r\nLet us take the first timestamp from above:\r\n```python\r\nt = pd.Timestamp("010120")\r\ntmax = t.max\r\n```\r\n\r\nWe get `tmax = Timestamp(\'292277026596-12-04 15:30:07\')` where it is at least not possible to create a Timestamp with a year greater than 9999.\r\n\r\n```python\r\nt_impossible = pd.Timestamp(10000,1,1)\r\n```\r\n\r\nlead to\r\n\r\n```\r\nValueError                                Traceback (most recent call last)\r\nCell In[29], line 1\r\n----> 1 pd.Timestamp(10000,1,1)\r\n\r\nFile ~/venv/myvenv/lib/python3.10/site-packages/pandas/_libs/tslibs/timestamps.pyx:1645, in pandas._libs.tslibs.timestamps.Timestamp.__new__()\r\n\r\nValueError: year 10000 is out of range\r\n```\r\n\r\nI even cannot count on a timestamp that is outside the max values (pd.Timestamp.max = Timestamp(\'2262-04-11 23:47:16.854775807\') and pd.Timestamp.min = Timestamp(\'1677-09-21 00:12:43.145224193\'))\r\n\r\nTo what extent is the behaviour intentional or erroneous?\r\n\r\n\r\nWith pandas 1.5.3 it was not possible to create timestamps greater than pd.Timestamp.max due to its ns-representation.\r\n\r\n\r\n\r\n\n\n### Expected Behavior\n\nI don\'t know if it is even a bug, but I would expect, that I can create timestamp (e.g. year > 10000) and that I can calculate with timestamps (e.g. 2300-01-01 + 100 days) [ not in every unit, but if the unit allows it, why not?\n\n### Installed Versions\n\nINSTALLED VERSIONS\r\n------------------\r\npython           : 3.10.2.final.0\r\npython-bits      : 64\r\nOS               : Darwin\r\nOS-release       : 22.1.0\r\nVersion          : Darwin Kernel Version 22.1.0: Sun Oct  9 20:14:54 PDT 2022; root:xnu-8792.41.9~2/RELEASE_X86_64\r\nmachine          : x86_64\r\nprocessor        : i386\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : de_DE.UTF-8\r\n\r\npandas           : 2.0.0rc1\r\nnumpy            : 1.23.5\r\npytz             : 2022.6\r\ndateutil         : 2.8.2\r\nsetuptools       : 65.6.3\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : 7.2.0\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.9.1\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : 2.9.5\r\njinja2           : 3.1.2\r\nIPython          : 8.7.0\r\npandas_datareader: None\r\nbs4              : 4.11.1\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : 2022.11.0\r\ngcsfs            : 2022.11.0\r\nmatplotlib       : 3.6.2\r\nnumba            : None\r\nnumexpr          : 2.8.4\r\nodfpy            : None\r\nopenpyxl         : 3.0.10\r\npanda ...
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52091/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52091/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52090',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52090/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52090/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52090/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52090',
#   'id': 1632582591,
#   'node_id': 'I_kwDOAA0YD85hTzu_',
#   'number': 52090,
#   'title': 'BUG: pandas.read_sql_table() returns incorrect data types ',
#   'user': {'login': 'Alper2022',
#    'id': 113861328,
#    'node_id': 'U_kgDOBsli0A',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/113861328?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Alper2022',
#    'html_url': 'https://github.com/Alper2022',
#    'followers_url': 'https://api.github.com/users/Alper2022/followers',
#    'following_url': 'https://api.github.com/users/Alper2022/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/Alper2022/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/Alper2022/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/Alper2022/subscriptions',
#    'organizations_url': 'https://api.github.com/users/Alper2022/orgs',
#    'repos_url': 'https://api.github.com/users/Alper2022/repos',
#    'events_url': 'https://api.github.com/users/Alper2022/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/Alper2022/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 1954720290,
#     'node_id': 'MDU6TGFiZWwxOTU0NzIwMjkw',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Needs%20Triage',
#     'name': 'Needs Triage',
#     'color': '0052cc',
#     'default': False,
#     'description': 'Issue that has not been reviewed by a pandas team member'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-03-20T17:42:09Z',
#   'updated_at': '2023-03-20T22:35:59Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\n\n- [X] I have checked that this issue has not already been reported.\n\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\n\n- [X] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\n\n\n### Reproducible Example\n\n```python\n### Push this to Postgresql ###\r\ncreate table product(\r\nproduct_id varchar(255) primary key not null,\r\nprice varchar(255) not null,\r\ngender varchar(255),\r\nname varchar(255) not null,\r\nrecommendable boolean not null,\r\nis_active boolean  not null,\r\nfk_event_number integer references event(event_number) not null\r\n);\r\n\r\n### call pandas function ###\r\n\r\ndf_products_db = pd.read_sql_table("product",engine.connect())\r\n\r\nprint(df_products_db.dtypes) # returns 4 object data types, should be strings\n```\n\n\n### Issue Description\n\nWhen using pandas.read_sql_table() to request data from a (in my case) localhost postgres database, the data types returned are different then the data types specified in the postgresql enviorment\n\n### Expected Behavior\n\nData types should be strings (as they are varchar(255) in the database), but return as object types\n\n### Installed Versions\n\n<details>\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 2e218d10984e9919f0296931d92ea851c6a6faf5\r\npython           : 3.10.6.final.0\r\npython-bits      : 64\r\nOS               : Linux\r\nOS-release       : 5.19.0-35-generic\r\nVersion          : #36~22.04.1-Ubuntu SMP PREEMPT_DYNAMIC Fri Feb 17 15:17:25 UTC 2\r\nmachine          : x86_64\r\nprocessor        : x86_64\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : en_US.UTF-8\r\nLOCALE           : en_US.UTF-8\r\n\r\npandas           : 1.5.3\r\nnumpy            : 1.24.1\r\npytz             : 2022.1\r\ndateutil         : 2.8.1\r\nsetuptools       : 59.6.0\r\npip              : 22.0.2\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : 4.8.0\r\nhtml5lib         : 1.1\r\npymysql          : None\r\npsycopg2         : 2.9.5\r\njinja2           : 3.1.2\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : 4.10.0\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : None\r\nfsspec           : None\r\ngcsfs            : None\r\nmatplotlib       : 3.6.3\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : None\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : 2.0.6\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nxlwt             : None\r\nzstandard        : None\r\ntzdata           : None\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52090/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52090/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52087',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
# ...
#    'gists_url': 'https://api.github.com/users/mroeschke/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/mroeschke/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/mroeschke/subscriptions',
#    'organizations_url': 'https://api.github.com/users/mroeschke/orgs',
#    'repos_url': 'https://api.github.com/users/mroeschke/repos',
#    'events_url': 'https://api.github.com/users/mroeschke/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/mroeschke/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 47232590,
#     'node_id': 'MDU6TGFiZWw0NzIzMjU5MA==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20SQL',
#     'name': 'IO SQL',
#     'color': '5319e7',
#     'default': False,
#     'description': 'to_sql, read_sql, read_sql_query'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': 'on-merge: backport to 2.0.x',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 39,
#    'closed_issues': 1641,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2023-03-20T20:37:55Z',
#    'due_on': '2023-03-06T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-03-17T20:26:04Z',
#   'updated_at': '2023-03-21T00:50:55Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52058',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52058',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52058.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52058.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #52046 (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nIncludes a fix for an oversight referenced in https://github.com/apache/arrow/issues/34614\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52058/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52058/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52057',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52057/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52057/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52057/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/pull/52057',
#   'id': 1629774463,
#   'node_id': 'PR_kwDOAA0YD85MVLIu',
#   'number': 52057,
#   'title': 'PERF: Fix performance regression in read_csv when converting datetimes',
#   'user': {'login': 'phofl',
#    'id': 61934744,
#    'node_id': 'MDQ6VXNlcjYxOTM0NzQ0',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/61934744?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/phofl',
#    'html_url': 'https://github.com/phofl',
#    'followers_url': 'https://api.github.com/users/phofl/followers',
#    'following_url': 'https://api.github.com/users/phofl/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/phofl/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/phofl/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/phofl/subscriptions',
#    'organizations_url': 'https://api.github.com/users/phofl/orgs',
#    'repos_url': 'https://api.github.com/users/phofl/repos',
#    'events_url': 'https://api.github.com/users/phofl/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/phofl/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 47229171,
#     'node_id': 'MDU6TGFiZWw0NzIyOTE3MQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/IO%20CSV',
#     'name': 'IO CSV',
#     'color': '5319e7',
#     'default': False,
#     'description': 'read_csv, to_csv'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': {'url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42',
#    'html_url': 'https://github.com/pandas-dev/pandas/milestone/42',
#    'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/milestones/42/labels',
#    'id': 1945020,
#    'node_id': 'MDk6TWlsZXN0b25lMTk0NTAyMA==',
#    'number': 42,
#    'title': '2.0',
#    'description': 'on-merge: backport to 2.0.x',
#    'creator': {'login': 'jreback',
#     'id': 953992,
#     'node_id': 'MDQ6VXNlcjk1Mzk5Mg==',
#     'avatar_url': 'https://avatars.githubusercontent.com/u/953992?v=4',
#     'gravatar_id': '',
#     'url': 'https://api.github.com/users/jreback',
#     'html_url': 'https://github.com/jreback',
#     'followers_url': 'https://api.github.com/users/jreback/followers',
#     'following_url': 'https://api.github.com/users/jreback/following{/other_user}',
#     'gists_url': 'https://api.github.com/users/jreback/gists{/gist_id}',
#     'starred_url': 'https://api.github.com/users/jreback/starred{/owner}{/repo}',
#     'subscriptions_url': 'https://api.github.com/users/jreback/subscriptions',
#     'organizations_url': 'https://api.github.com/users/jreback/orgs',
#     'repos_url': 'https://api.github.com/users/jreback/repos',
#     'events_url': 'https://api.github.com/users/jreback/events{/privacy}',
#     'received_events_url': 'https://api.github.com/users/jreback/received_events',
#     'type': 'User',
#     'site_admin': False},
#    'open_issues': 39,
#    'closed_issues': 1641,
#    'state': 'open',
#    'created_at': '2016-08-16T13:21:24Z',
#    'updated_at': '2023-03-20T20:37:55Z',
#    'due_on': '2023-03-06T08:00:00Z',
#    'closed_at': None},
#   'comments': 0,
#   'created_at': '2023-03-17T18:48:12Z',
#   'updated_at': '2023-03-17T22:10:44Z',
#   'closed_at': None,
#   'author_association': 'MEMBER',
#   'active_lock_reason': None,
#   'draft': False,
#   'pull_request': {'url': 'https://api.github.com/repos/pandas-dev/pandas/pulls/52057',
#    'html_url': 'https://github.com/pandas-dev/pandas/pull/52057',
#    'diff_url': 'https://github.com/pandas-dev/pandas/pull/52057.diff',
#    'patch_url': 'https://github.com/pandas-dev/pandas/pull/52057.patch',
#    'merged_at': None},
#   'body': '- [ ] closes #xxxx (Replace xxxx with the GitHub issue number)\r\n- [ ] [Tests added and passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#writing-tests) if fixing a bug or adding a new feature\r\n- [ ] All [code checks passed](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#pre-commit).\r\n- [ ] Added [type annotations](https://pandas.pydata.org/pandas-docs/dev/development/contributing_codebase.html#type-hints) to new arguments/methods/functions.\r\n- [ ] Added an entry in the latest `doc/source/whatsnew/vX.X.X.rst` file if fixing a bug or adding a new feature.\r\n\r\nthe read-only pr changed this to _values which returns a DatetimeArray instead of a ndarray, which caused a performance regression \r\n\r\nhttps://asv-runner.github.io/asv-collection/pandas/#io.csv.ReadCSVConcatDatetime.time_read_csv',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52057/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52057/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None},
#  {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52056',
#   'repository_url': 'https://api.github.com/repos/pandas-dev/pandas',
#   'labels_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52056/labels{/name}',
#   'comments_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52056/comments',
#   'events_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52056/events',
#   'html_url': 'https://github.com/pandas-dev/pandas/issues/52056',
#   'id': 1629697929,
#   'node_id': 'I_kwDOAA0YD85hIzeJ',
#   'number': 52056,
#   'title': 'BUG: Pyarrow scalars inferred as object dtype with arrow backend enabled whwn assigning a new column',
#   'user': {'login': 'rohanjain101',
#    'id': 38412262,
#    'node_id': 'MDQ6VXNlcjM4NDEyMjYy',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/38412262?v=4',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/rohanjain101',
#    'html_url': 'https://github.com/rohanjain101',
#    'followers_url': 'https://api.github.com/users/rohanjain101/followers',
#    'following_url': 'https://api.github.com/users/rohanjain101/following{/other_user}',
#    'gists_url': 'https://api.github.com/users/rohanjain101/gists{/gist_id}',
#    'starred_url': 'https://api.github.com/users/rohanjain101/starred{/owner}{/repo}',
#    'subscriptions_url': 'https://api.github.com/users/rohanjain101/subscriptions',
#    'organizations_url': 'https://api.github.com/users/rohanjain101/orgs',
#    'repos_url': 'https://api.github.com/users/rohanjain101/repos',
#    'events_url': 'https://api.github.com/users/rohanjain101/events{/privacy}',
#    'received_events_url': 'https://api.github.com/users/rohanjain101/received_events',
#    'type': 'User',
#    'site_admin': False},
#   'labels': [{'id': 76811,
#     'node_id': 'MDU6TGFiZWw3NjgxMQ==',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Bug',
#     'name': 'Bug',
#     'color': 'e10c02',
#     'default': False,
#     'description': None},
#    {'id': 2822098,
#     'node_id': 'MDU6TGFiZWwyODIyMDk4',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Indexing',
#     'name': 'Indexing',
#     'color': '0b02e1',
#     'default': False,
#     'description': 'Related to indexing on series/frames, not to indexes themselves'},
#    {'id': 3303158446,
#     'node_id': 'MDU6TGFiZWwzMzAzMTU4NDQ2',
#     'url': 'https://api.github.com/repos/pandas-dev/pandas/labels/Arrow',
#     'name': 'Arrow',
#     'color': 'f9d0c4',
#     'default': False,
#     'description': 'pyarrow functionality'}],
#   'state': 'open',
#   'locked': False,
#   'assignee': None,
#   'assignees': [],
#   'milestone': None,
#   'comments': 2,
#   'created_at': '2023-03-17T17:41:58Z',
#   'updated_at': '2023-03-17T20:38:23Z',
#   'closed_at': None,
#   'author_association': 'NONE',
#   'active_lock_reason': None,
#   'body': '### Pandas version checks\r\n\r\n- [X] I have checked that this issue has not already been reported.\r\n\r\n- [X] I have confirmed this bug exists on the [latest version](https://pandas.pydata.org/docs/whatsnew/index.html) of pandas.\r\n\r\n- [ ] I have confirmed this bug exists on the [main branch](https://pandas.pydata.org/docs/dev/getting_started/install.html#installing-the-development-version-of-pandas) of pandas.\r\n\r\n\r\n### Reproducible Example\r\n\r\n```python\r\n>>> pd.options.mode.dtype_backend = \'pyarrow\'\r\n>>> ser = pd.Series([1,2,3], dtype="int64[pyarrow]")\r\n>>> df2 = pd.DataFrame({"A": ser})\r\n>>> scalar = pa.scalar(23)\r\n>>> scalar\r\n<pyarrow.Int64Scalar: 23>\r\n>>> df2["B"] = scalar\r\n>>> df2["B"].dtype\r\ndtype(\'O\')\r\n>>>\r\n```\r\n\r\n\r\n### Issue Description\r\n\r\nSince "B" is a brand new column, the dtype should be "int64[pyarrow]", not object.\r\n\r\n### Expected Behavior\r\n\r\nWith numpy scalars, the type inferred is a numpy type, so with a pyarrow scalar, I expect the type to be an arrow type, in this case, "int64[pyarrow]", not object.\r\n\r\n### Installed Versions\r\n\r\n<details>\r\n\r\n>>> pd.show_versions()\r\n\r\nINSTALLED VERSIONS\r\n------------------\r\ncommit           : 1a2e300170efc08cb509a0b4ff6248f8d55ae777\r\npython           : 3.8.10.final.0\r\npython-bits      : 64\r\nOS               : Windows\r\nOS-release       : 10\r\nVersion          : 10.0.22621\r\nmachine          : AMD64\r\nprocessor        : Intel64 Family 6 Model 85 Stepping 7, GenuineIntel\r\nbyteorder        : little\r\nLC_ALL           : None\r\nLANG             : None\r\nLOCALE           : English_United States.1252\r\n\r\npandas           : 2.0.0rc0\r\nnumpy            : 1.24.2\r\npytz             : 2022.7.1\r\ndateutil         : 2.8.2\r\nsetuptools       : 67.2.0\r\npip              : 22.3.1\r\nCython           : None\r\npytest           : None\r\nhypothesis       : None\r\nsphinx           : None\r\nblosc            : None\r\nfeather          : None\r\nxlsxwriter       : None\r\nlxml.etree       : None\r\nhtml5lib         : None\r\npymysql          : None\r\npsycopg2         : None\r\njinja2           : None\r\nIPython          : None\r\npandas_datareader: None\r\nbs4              : None\r\nbottleneck       : None\r\nbrotli           : None\r\nfastparquet      : 2023.2.0\r\nfsspec           : 2023.3.0\r\ngcsfs            : None\r\nmatplotlib       : None\r\nnumba            : None\r\nnumexpr          : None\r\nodfpy            : None\r\nopenpyxl         : None\r\npandas_gbq       : None\r\npyarrow          : 11.0.0\r\npyreadstat       : None\r\npyxlsb           : None\r\ns3fs             : None\r\nscipy            : None\r\nsnappy           : None\r\nsqlalchemy       : None\r\ntables           : None\r\ntabulate         : None\r\nxarray           : None\r\nxlrd             : None\r\nzstandard        : None\r\ntzdata           : None\r\nqtpy             : None\r\npyqt5            : None\r\n>>>\r\n\r\n</details>\r\n',
#   'reactions': {'url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52056/reactions',
#    'total_count': 0,
#    '+1': 0,
#    '-1': 0,
#    'laugh': 0,
#    'hooray': 0,
#    'confused': 0,
#    'heart': 0,
#    'rocket': 0,
#    'eyes': 0},
#   'timeline_url': 'https://api.github.com/repos/pandas-dev/pandas/issues/52056/timeline',
#   'performed_via_github_app': None,
#   'state_reason': None}]

# %%
data[0]['title']
# Out:
# 'BUG: `bar_label()` on Series bar plot (`.plot()`) displays values off by 1'

# %%
issues = pd.DataFrame(data,columns=['numner','title','labels','state'])

# %%
issues
# Out:
#     numner                                              title  \
# 0      NaN  BUG: `bar_label()` on Series bar plot (`.plot(...
# 1      NaN  DOC: improve (dark) theme getting started tuto...
# 2      NaN         ENH: support na_action in SparseArray.map
# 3      NaN  BUG: SparseArray.map allows the fill value to ...
# 4      NaN  BUG: inconsistent returned types for `pd.to_da...
# 5      NaN  BUG: AttributeError raised with pd.concat betw...
# 6      NaN  DOC: Remove old SparseDataFrame/SparseSeries r...
# 7      NaN  BUG or as expected/designed?: Generating times...
# 8      NaN  BUG: pandas.read_sql_table() returns incorrect...
# 9      NaN                 BUG: Fix some more arrow CSV tests
# 10     NaN                                              BUG:
# 11     NaN      BUG: Cumprod failing with type float[pyarrow]
# 12     NaN  PERF: improve 2D array access / transpose() fo...
# 13     NaN  DataFrame pivot_table nunique aggfunc test GH#...
# 14     NaN           DEPR: be stricter in assert_almost_equal
# 15     NaN  PERF: performance problem when comparing times...
# 16     NaN  BUG: Fix regression when using Series with arr...
# 17     NaN    BUG: Arrow setitem segfaults when len > 145 000
# 18     NaN                    WEB: Sort PDEPs by their number
# 19     NaN  PERF: group by manipulation is slower with new...
# 20     NaN  BUG: to_excel() missing values for specific da...
# 21     NaN  CoW: Switch to copy=False everywhere for Serie...
# 22     NaN  Frequency: raise warnings when using ‘M’ frequ...
# 23     NaN         CoW: Delay copy when enlarging df with loc
# 24     NaN  CoW: Delay copy when inserting Series into Dat...
# 25     NaN   API CoW: Return read_only NumPy array from ravel
# 26     NaN  BUG: python crashes on filtering with `.loc` o...
# 27     NaN                BUG: to_sql with ArrowExtesionArray
# 28     NaN  PERF: Fix performance regression in read_csv w...
# 29     NaN  BUG: Pyarrow scalars inferred as object dtype ...
#
#                                                labels state
# 0   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 1                                                  []  open
# 2                                                  []  open
# 3   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 4   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 5   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 6   [{'id': 134699, 'node_id': 'MDU6TGFiZWwxMzQ2OT...  open
# 7   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 8   [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 9   [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 10  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 11  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 12  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 13  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 14  [{'id': 127685, 'node_id': 'MDU6TGFiZWwxMjc2OD...  open
# 15  [{'id': 8935311, 'node_id': 'MDU6TGFiZWw4OTM1M...  open
# 16  [{'id': 32815646, 'node_id': 'MDU6TGFiZWwzMjgx...  open
# 17  [{'id': 3303158446, 'node_id': 'MDU6TGFiZWwzMz...  open
# 18  [{'id': 1508144531, 'node_id': 'MDU6TGFiZWwxNT...  open
# 19  [{'id': 233160, 'node_id': 'MDU6TGFiZWwyMzMxNj...  open
# 20  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 21  [{'id': 2085877452, 'node_id': 'MDU6TGFiZWwyMD...  open
# 22                                                 []  open
# 23  [{'id': 2085877452, 'node_id': 'MDU6TGFiZWwyMD...  open
# 24  [{'id': 2085877452, 'node_id': 'MDU6TGFiZWwyMD...  open
# 25  [{'id': 2085877452, 'node_id': 'MDU6TGFiZWwyMD...  open
# 26  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open
# 27  [{'id': 47232590, 'node_id': 'MDU6TGFiZWw0NzIz...  open
# 28  [{'id': 47229171, 'node_id': 'MDU6TGFiZWw0NzIy...  open
# 29  [{'id': 76811, 'node_id': 'MDU6TGFiZWw3NjgxMQ=...  open

# %%
import sqlite3

# %%
query = """
 .....: CREATE TABLE test
 .....: (a VARCHAR(20), b VARCHAR(20),
 .....: c REAL, d INTEGER
 .....: );"""

# %%
con=sqlite3.connect('mydata.sqlite')

# %%
con.execute(query)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 con.execute(query)
#
# OperationalError: table test already exists

# %%
con.commit()

# %%
data =[ ('Atlanta', 'Georgia', 1.25, 6),('Tallahassee', 'Florida', 2.6, 3),( 'Sacramento', 'California', 1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

# %%
con.executemany(stmt,data)

# %%
con.commit()
